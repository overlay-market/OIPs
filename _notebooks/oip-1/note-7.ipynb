# %%
import pandas as pd
import numpy as np

# %%
# Import csv data for last 30 days of priceCumulative values from csv/data-1624665179.csv
df_raw = pd.read_csv("csv/data-1624665179.csv")
df_raw
# Out:
#         result  table                            _start  \
# 0      _result      0  2021-05-26 23:52:57.843291+00:00
# 1      _result      0  2021-05-26 23:52:57.843291+00:00
# 2      _result      0  2021-05-26 23:52:57.843291+00:00
# 3      _result      0  2021-05-26 23:52:57.843291+00:00
# 4      _result      0  2021-05-26 23:52:57.843291+00:00
# ...        ...    ...                               ...
# 81977  _result     29  2021-05-26 23:52:57.843291+00:00
# 81978  _result     29  2021-05-26 23:52:57.843291+00:00
# 81979  _result     29  2021-05-26 23:52:57.843291+00:00
# 81980  _result     29  2021-05-26 23:52:57.843291+00:00
# 81981  _result     29  2021-05-26 23:52:57.843291+00:00
#
#                                   _stop                      _time  \
# 0      2021-06-25 23:52:57.843291+00:00  2021-05-27 00:06:58+00:00
# 1      2021-06-25 23:52:57.843291+00:00  2021-05-27 00:13:42+00:00
# 2      2021-06-25 23:52:57.843291+00:00  2021-05-27 00:31:02+00:00
# 3      2021-06-25 23:52:57.843291+00:00  2021-05-27 00:31:40+00:00
# 4      2021-06-25 23:52:57.843291+00:00  2021-05-27 00:50:25+00:00
# ...                                 ...                        ...
# 81977  2021-06-25 23:52:57.843291+00:00  2021-06-25 23:03:53+00:00
# 81978  2021-06-25 23:52:57.843291+00:00  2021-06-25 23:07:41+00:00
# 81979  2021-06-25 23:52:57.843291+00:00  2021-06-25 23:25:47+00:00
# 81980  2021-06-25 23:52:57.843291+00:00  2021-06-25 23:29:19+00:00
# 81981  2021-06-25 23:52:57.843291+00:00  2021-06-25 23:44:51+00:00
#
#              _value            _field _measurement                      id  \
# 0      1.259956e+43  price1Cumulative          mem   Sushiswap: UNI / WETH
# 1      1.259976e+43  price1Cumulative          mem   Sushiswap: UNI / WETH
# 2      1.260029e+43  price1Cumulative          mem   Sushiswap: UNI / WETH
# 3      1.260031e+43  price1Cumulative          mem   Sushiswap: UNI / WETH
# 4      1.260089e+43  price1Cumulative          mem   Sushiswap: UNI / WETH
# ...             ...               ...          ...                     ...
# 81977  1.138973e+31  price1Cumulative          mem  Sushiswap: WETH / WBTC
# 81978  1.138973e+31  price1Cumulative          mem  Sushiswap: WETH / WBTC
# 81979  1.138976e+31  price1Cumulative          mem  Sushiswap: WETH / WBTC
# 81980  1.138977e+31  price1Cumulative          mem  Sushiswap: WETH / WBTC
# 81981  1.138980e+31  price1Cumulative          mem  Sushiswap: WETH / WBTC
#
#             influx-sushi token0_name token1_name            type
# 0      ingest-data-frame         UNI        WETH  metrics-hourly
# 1      ingest-data-frame         UNI        WETH  metrics-hourly
# 2      ingest-data-frame         UNI        WETH  metrics-hourly
# 3      ingest-data-frame         UNI        WETH  metrics-hourly
# 4      ingest-data-frame         UNI        WETH  metrics-hourly
# ...                  ...         ...         ...             ...
# 81977  ingest-data-frame        WETH        WBTC  metrics-hourly
# 81978  ingest-data-frame        WETH        WBTC  metrics-hourly
# 81979  ingest-data-frame        WETH        WBTC  metrics-hourly
# 81980  ingest-data-frame        WETH        WBTC  metrics-hourly
# 81981  ingest-data-frame        WETH        WBTC  metrics-hourly
#
# [81982 rows x 13 columns]

# %%
# Filter for cols we care about: [id, _time, _field, _value] and sort by time
df = df_raw.filter(items=['id', '_time', '_field', '_value'])
df = df.sort_values(by='_time', ignore_index=True)
df
# Out:
#                             id                      _time            _field  \
# 0       Sushiswap: COMP / WETH  2021-05-26 23:55:41+00:00  price0Cumulative
# 1       Sushiswap: COMP / WETH  2021-05-26 23:55:41+00:00  price1Cumulative
# 2        Sushiswap: MKR / WETH  2021-05-27 00:01:19+00:00  price0Cumulative
# 3        Sushiswap: MKR / WETH  2021-05-27 00:01:19+00:00  price1Cumulative
# 4        Sushiswap: SNX / WETH  2021-05-27 00:01:19+00:00  price0Cumulative
# ...                        ...                        ...               ...
# 81977  Sushiswap: SUSHI / WETH  2021-06-25 23:49:11+00:00  price0Cumulative
# 81978   Sushiswap: RUNE / WETH  2021-06-25 23:49:11+00:00  price0Cumulative
# 81979    Sushiswap: WETH / DAI  2021-06-25 23:49:11+00:00  price1Cumulative
# 81980    Sushiswap: UNI / WETH  2021-06-25 23:49:12+00:00  price1Cumulative
# 81981    Sushiswap: UNI / WETH  2021-06-25 23:49:12+00:00  price0Cumulative
#
#              _value
# 0      2.892970e+40
# 1      4.967069e+41
# 2      1.383139e+41
# 3      9.427158e+40
# 4      1.178501e+39
# ...             ...
# 81977  6.736688e+38
# 81978  2.776636e+38
# 81979  1.864844e+44
# 81980  1.401652e+43
# 81981  1.323540e+39
#
# [81982 rows x 4 columns]

# %%
# Examine stats for two pairs: WETH / DAI (less volatile) ...
df_weth_dai = df[(df['id'] == "Sushiswap: WETH / DAI") & (df['_field'] == "price1Cumulative")]
df_weth_dai
# Out:
#                           id                      _time            _field  \
# 13     Sushiswap: WETH / DAI  2021-05-27 00:04:08+00:00  price1Cumulative
# 43     Sushiswap: WETH / DAI  2021-05-27 00:17:51+00:00  price1Cumulative
# 76     Sushiswap: WETH / DAI  2021-05-27 00:30:06+00:00  price1Cumulative
# 107    Sushiswap: WETH / DAI  2021-05-27 00:41:13+00:00  price1Cumulative
# 129    Sushiswap: WETH / DAI  2021-05-27 00:52:12+00:00  price1Cumulative
# ...                      ...                        ...               ...
# 81881  Sushiswap: WETH / DAI  2021-06-25 23:03:57+00:00  price1Cumulative
# 81896  Sushiswap: WETH / DAI  2021-06-25 23:14:19+00:00  price1Cumulative
# 81924  Sushiswap: WETH / DAI  2021-06-25 23:23:57+00:00  price1Cumulative
# 81954  Sushiswap: WETH / DAI  2021-06-25 23:38:10+00:00  price1Cumulative
# 81979  Sushiswap: WETH / DAI  2021-06-25 23:49:11+00:00  price1Cumulative
#
#              _value
# 13     1.539463e+44
# 43     1.539585e+44
# 76     1.539693e+44
# 107    1.539790e+44
# 129    1.539886e+44
# ...             ...
# 81881  1.864589e+44
# 81896  1.864647e+44
# 81924  1.864701e+44
# 81954  1.864782e+44
# 81979  1.864844e+44
#
# [3754 rows x 4 columns]

# %%
# ... and ALCX / WETH (more volatile)
df_alcx_weth = df[(df['id'] == "Sushiswap: ALCX / WETH") & (df['_field'] == "price1Cumulative")]
df_alcx_weth
# Out:
#                            id                      _time            _field  \
# 15     Sushiswap: ALCX / WETH  2021-05-27 00:04:58+00:00  price1Cumulative
# 55     Sushiswap: ALCX / WETH  2021-05-27 00:20:01+00:00  price1Cumulative
# 69     Sushiswap: ALCX / WETH  2021-05-27 00:28:45+00:00  price1Cumulative
# 95     Sushiswap: ALCX / WETH  2021-05-27 00:37:25+00:00  price1Cumulative
# 123    Sushiswap: ALCX / WETH  2021-05-27 00:50:24+00:00  price1Cumulative
# ...                       ...                        ...               ...
# 81873  Sushiswap: ALCX / WETH  2021-06-25 23:02:38+00:00  price1Cumulative
# 81892  Sushiswap: ALCX / WETH  2021-06-25 23:09:36+00:00  price1Cumulative
# 81926  Sushiswap: ALCX / WETH  2021-06-25 23:25:45+00:00  price1Cumulative
# 81943  Sushiswap: ALCX / WETH  2021-06-25 23:34:10+00:00  price1Cumulative
# 81961  Sushiswap: ALCX / WETH  2021-06-25 23:44:50+00:00  price1Cumulative
#
#              _value
# 15     2.615926e+40
# 55     2.616081e+40
# 69     2.616171e+40
# 95     2.616260e+40
# 123    2.616393e+40
# ...             ...
# 81873  2.954404e+40
# 81892  2.954439e+40
# 81926  2.954520e+40
# 81943  2.954562e+40
# 81961  2.954615e+40
#
# [3623 rows x 4 columns]
