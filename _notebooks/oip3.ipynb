# %%
import matplotlib.pyplot as plt
from functools import partial
import numpy as np

# %%
def q(lE, lX, eX):
    return (lE - 1)/(lX*eX + lE)

# %%
R = np.arange(-1,1.1,.1)
lE = 1
lX = 1
arr1 = q(2, 1, R)
plt.plot(arr1)
arr2 = q(2, 1, R)
plt.plot(arr2)
plt.axvline(10, c='k', alpha=.5)
plt.show()

# %%
lE = 2.1
lX = 2
def get_q(lE, lX, R):
    for r in R:
        yield(q(lE,lX,R,r))
def Q(lE,lX,R):
    return np.array(list(get_q(lE,lX,R)))
Q(lE,lX,R)
q(lE,lX,R[2],R)
q(2.1,2,.1,-.9)
# Out:
# 9.166666666666677

# %%
plt.imshow(Q(lE,lX,R), cmap='viridis')
plt.colorbar()
plt.show()

# %%
import sympy as sp

x = sp.Symbol('x')
l = sp.Function('l')(x)
k = sp.Symbol('kappa')

#f = (l-1)/(k*x + l)

A = sp.diff((l-1)/(k*x + l), x)

# %%
A.simplify().factor(sp.diff(l, x), k)
# Out:
# (kappa*x*Derivative(l(x), x) + kappa*(1 - l(x)) + Derivative(l(x), x))/(kappa*x + l(x))**2

# %%
S = np.arange(1,5,.2)
plt.plot((S - 1)/S, marker='.')
plt.show()

# %%
plt.plot(R + 2)
plt.show()

# %%
R
# Out:
# array([-1.00000000e+00, -9.00000000e-01, -8.00000000e-01, -7.00000000e-01,
#        -6.00000000e-01, -5.00000000e-01, -4.00000000e-01, -3.00000000e-01,
#        -2.00000000e-01, -1.00000000e-01, -2.22044605e-16,  1.00000000e-01,
#         2.00000000e-01,  3.00000000e-01,  4.00000000e-01,  5.00000000e-01,
#         6.00000000e-01,  7.00000000e-01,  8.00000000e-01,  9.00000000e-01,
#         1.00000000e+00])
